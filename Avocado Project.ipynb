# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avocado.csv')
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# ...

# %%
df.shape
# Out:
# (18249, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
df.describe()
# Out:
#          Unnamed: 0  AveragePrice  Total Volume          4046          4225  \
# count  18249.000000  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04
# mean      24.232232      1.405978  8.506440e+05  2.930084e+05  2.951546e+05
# std       15.481045      0.402677  3.453545e+06  1.264989e+06  1.204120e+06
# min        0.000000      0.440000  8.456000e+01  0.000000e+00  0.000000e+00
# 25%       10.000000      1.100000  1.083858e+04  8.540700e+02  3.008780e+03
# 50%       24.000000      1.370000  1.073768e+05  8.645300e+03  2.906102e+04
# 75%       38.000000      1.660000  4.329623e+05  1.110202e+05  1.502069e+05
# max       52.000000      3.250000  6.250565e+07  2.274362e+07  2.047057e+07
#
#                4770    Total Bags    Small Bags    Large Bags    XLarge Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000
# mean   2.283974e+04  2.396392e+05  1.821947e+05  5.433809e+04    3106.426507
# ...

# %%
df['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %%
df['type']=df['type'].map({'conventional':0, 'organic':1})

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags  type  year  region
# 0   48.16     8696.87     8603.62       93.25          0.0     0  2015  Albany
# 1   58.33     9505.56     9408.07       97.49          0.0     0  2015  Albany
# 2  130.50     8145.35     8042.21      103.14          0.0     0  2015  Albany
# 3   72.58     5811.16     5677.40      133.76          0.0     0  2015  Albany
# 4   75.78     6183.95     5986.26      197.69          0.0     0  2015  Albany

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
sns.jointplot(x='AveragePrice',y='year',data=df)
xlabel="Average Price"
ylabel = "Year"

# %%
df['Date']=df['Date'].apply(pd.to_datetime)
df['Date']
# Out:
# 0       2015-12-27
# 1       2015-12-20
# 2       2015-12-13
# 3       2015-12-06
# 4       2015-11-29
#            ...
# 18244   2018-02-04
# 18245   2018-01-28
# 18246   2018-01-21
# 18247   2018-01-14
# 18248   2018-01-07
# Name: Date, Length: 18249, dtype: datetime64[ns]

# %%
df['month']=df['Date'].apply(lambda x:x.month)
df
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df1=df.copy()
df1
# Out:
#        Unnamed: 0       Date  AveragePrice  Total Volume     4046       4225  \
# 0               0 2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1 2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2 2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3 2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4 2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...        ...           ...           ...      ...        ...
# 18244           7 2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8 2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9 2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10 2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11 2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df1['month']=df1['Date'].apply(lambda x:x.month)

# %%
df1['month']=df1['month'].map({1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sep',10:'Oct',11:'Nov',12:'Dec'})

# %%
df1['month']
# Out:
# 0        Dec
# 1        Dec
# 2        Dec
# 3        Dec
# 4        Nov
#         ...
# 18244    Feb
# 18245    Jan
# 18246    Jan
# 18247    Jan
# 18248    Jan
# Name: month, Length: 18249, dtype: object

# %%
sns.countplot(x='month', data=df1)
# Out:
# <Axes: xlabel='month', ylabel='count'>

# %%
dummies=pd.get_dummies(df1[['year','region','month']])
dummies.columns
# Out:
# Index(['year', 'region_Albany', 'region_Atlanta', 'region_BaltimoreWashington',
#        'region_Boise', 'region_Boston', 'region_BuffaloRochester',
#        'region_California', 'region_Charlotte', 'region_Chicago',
#        'region_CincinnatiDayton', 'region_Columbus', 'region_DallasFtWorth',
#        'region_Denver', 'region_Detroit', 'region_GrandRapids',
#        'region_GreatLakes', 'region_HarrisburgScranton',
#        'region_HartfordSpringfield', 'region_Houston', 'region_Indianapolis',
#        'region_Jacksonville', 'region_LasVegas', 'region_LosAngeles',
#        'region_Louisville', 'region_MiamiFtLauderdale', 'region_Midsouth',
#        'region_Nashville', 'region_NewOrleansMobile', 'region_NewYork',
#        'region_Northeast', 'region_NorthernNewEngland', 'region_Orlando',
#        'region_Philadelphia', 'region_PhoenixTucson', 'region_Pittsburgh',
#        'region_Plains', 'region_Portland', 'region_RaleighGreensboro',
# ...

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region', 'month'],
#       dtype='object')

# %%
x=pd.concat([df1[['Total Volume', '4046', '4225','4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type']],dummies], axis=1)

# %%
if 'AveragePrice'in x.columns:
    print('present')
else:
    pass

# %%
y=df1['AveragePrice']

# %%
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.2, random_state=45)

# %%
x_train
# Out:
#        Total Volume       4046        4225      4770  Total Bags  Small Bags  \
# 7373     1208035.40  555816.37   227846.11   9212.36   415160.56   330740.57
# 7314      344203.81   17554.66   195308.13    131.09   131209.93   114735.77
# 14388       1792.53     123.09      853.68    192.57      623.19      123.53
# 4779      290633.33   61313.27   145758.08  26481.58    57080.40    52157.37
# 6797     1865690.48  837463.16   357662.06  84556.11   586009.15   543636.79
# ...             ...        ...         ...       ...         ...         ...
# 8928      367903.88  106372.21    91013.42   5010.88   165507.37   156789.32
# 7139     1221327.78   36138.61   791416.43   4113.73   389659.01   340915.45
# 4306     1455656.40   18107.83  1074827.27   2066.31   360654.99   317977.04
# 2164      458191.52  283530.10   131772.59   9903.23    32985.60    29400.09
# 1297      405138.19  285204.29    42798.99     42.64    77092.27    41312.00
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
s=scaler.fit(x_train[['Total Volume', '4046', '4225','4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags']])

# %%
x_train
# Out:
#        Total Volume       4046        4225      4770  Total Bags  Small Bags  \
# 7373     1208035.40  555816.37   227846.11   9212.36   415160.56   330740.57
# 7314      344203.81   17554.66   195308.13    131.09   131209.93   114735.77
# 14388       1792.53     123.09      853.68    192.57      623.19      123.53
# 4779      290633.33   61313.27   145758.08  26481.58    57080.40    52157.37
# 6797     1865690.48  837463.16   357662.06  84556.11   586009.15   543636.79
# ...             ...        ...         ...       ...         ...         ...
# 8928      367903.88  106372.21    91013.42   5010.88   165507.37   156789.32
# 7139     1221327.78   36138.61   791416.43   4113.73   389659.01   340915.45
# 4306     1455656.40   18107.83  1074827.27   2066.31   360654.99   317977.04
# 2164      458191.52  283530.10   131772.59   9903.23    32985.60    29400.09
# 1297      405138.19  285204.29    42798.99     42.64    77092.27    41312.00
#
# ...

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error,r2_score

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)
y_predict
# Out:
# array([1.16602731, 1.76459187, 1.78567936, ..., 1.25986525, 1.51565395,
#        1.51585081])

# %%
mae=mean_absolute_error(y_test,y_predict)
mse=mean_squared_error(y_test,y_predict)
r2=r2_score(y_test,y_predict)

# %%
mae
# Out:
# 0.18804118190711983

# %%
mse
# Out:
# 0.061892945352382704

# %%
r2
# Out:
# 0.6179930317153908

# %%
from sklearn.ensemble import RandomForestRegressor
rdr = RandomForestRegressor()
rdr.fit(x_train,y_train)
pred=rdr.predict(x_test)

# %%
print('MAE:',mean_absolute_error(y_test, pred))
print('MSE:',mean_squared_error(y_test, pred))
print('RMSE:', np.sqrt(mean_squared_error(y_test, pred)))
# Out:
# MAE: 0.12708069045825057
# MSE: 0.03263352738543735
# RMSE: 0.18064752250013658
